# %%
import sqlite3
import pandas as pd

# %%
# Create the connection
conn = sqlite3.connect(r'database.sqlite')

# create the dataframe from a query
df = pd.read_sql_query("select * from reviews left join genres on reviews.reviewid = genres.reviewid where artist = 'massive attack' ", conn)

# %%
df
# Out:
#    reviewid               title          artist  \
# 0     22703           mezzanine  massive attack
# 1     21553    ritual spirit ep  massive attack
# 2     21553    ritual spirit ep  massive attack
# 3     17384          blue lines  massive attack
# 4     14881        atlas air ep  massive attack
# 5     14881        atlas air ep  massive attack
# 6     13864          heligoland  massive attack
# 7     13574  splitting the atom  massive attack
# 8      5137           collected  massive attack
# 9      5136   danny the dog ost  massive attack
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/21553-ritu...    7.0               0
# 2  http://pitchfork.com/reviews/albums/21553-ritu...    7.0               0
# 3  http://pitchfork.com/reviews/albums/17384-blue...    9.0               1
# ...
